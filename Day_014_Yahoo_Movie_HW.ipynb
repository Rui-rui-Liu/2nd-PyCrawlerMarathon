# %% [markdown]
# # YAHOO電影爬蟲練習
# ## 練習爬取電影放映資訊。必須逐步獲取電影的代號、放映地區、放映日期後，再送出查詢給伺服器。

# %%
import requests
import re
from bs4 import BeautifulSoup

# %% [markdown]
# ### 先搜尋全部的電影代號(ID)資訊

# %%
# 查看目前上映那些電影，並擷取出其ID資訊
url = 'https://movies.yahoo.com.tw/'
resp = requests.get(url)
resp.encoding = 'utf-8'

soup = BeautifulSoup(resp.text, 'lxml')
html = soup.find("select", attrs={'name':'movie_id'})
movie_item = html.find_all("option", attrs={'data-name':re.compile('.*')})

for p in movie_item:
    print("Movie: %s, ID: %s" % (p["data-name"], p["value"]))
# Out:
# Movie: 電影版 地獄少女, ID: 10525
# Movie: 刺激1995, ID: 10518
# Movie: 通靈少年2020, ID: 10517
# Movie: 安雅的回家路, ID: 10516
# Movie: 牆內的房客, ID: 10512
# Movie: 南山的部長們, ID: 10509
# Movie: 另類神父, ID: 10500
# Movie: 破．局, ID: 10496
# Movie: 劇場版 不起眼女主角培育法 Fine, ID: 10486
# Movie: 複製柔伊, ID: 10455
# Movie: 練愛iNG, ID: 10442
# Movie: 鋼鐵勳章, ID: 10432
# Movie: 我，最親愛的, ID: 10503
# Movie: 血衛, ID: 10469
# Movie: 導演先生的完美假期, ID: 10545
# Movie: 大地蜜語, ID: 10513
# Movie: 狂飆一夢, ID: 10506
# Movie: 親愛的莎瑪, ID: 10491
# Movie: 大畫特務, ID: 10478
# Movie: 戰慄糖果屋, ID: 10472
# Movie: 失戀殺人：三角禁戀, ID: 10465
# Movie: 明明會說話, ID: 10440
# Movie: 艾瑪, ID: 10396
# Movie: 罪樂園, ID: 10349
# Movie: 千日千夜, ID: 10490
# Movie: 鳴鳥不飛：烏雲密布, ID: 10458
# Movie: 哥布林殺手 劇場版, ID: 10438
# Movie: 女鬼橋, ID: 10437
# Movie: 怨咒, ID: 10421
# Movie: 娘娘腔日記, ID: 10401
# Movie: 極地守護犬, ID: 10383
# Movie: 叔．叔, ID: 10371
# Movie: 隱形人, ID: 10359
# Movie: 失路人, ID: 10498
# Movie: 電影音效傳奇：好萊塢之聲, ID: 10484
# Movie: 悲慘世界, ID: 10479
# Movie: 吹哨奇案, ID: 10475
# Movie: 陰櫥, ID: 10457
# Movie: 絕命大平台, ID: 10447
# Movie: 李察朱威爾事件, ID: 10368
# Movie: 音速小子, ID: 9246
# Movie: 逃出夢幻島, ID: 10485
# Movie: 雨天．紐約, ID: 10476
# Movie: 超＂人＂氣動物園, ID: 10445
# Movie: 就愛斷捨離, ID: 10436
# Movie: 全境失控, ID: 10426
# Movie: 猛禽小隊：小丑女大解放, ID: 10268
# Movie: 紅鞋公主與七矮人, ID: 10417
# Movie: 1917, ID: 10189
# Movie: 你的情歌, ID: 10407
# Movie: 紳士追殺令, ID: 10317
# Movie: 她們, ID: 10202
# Movie: 變身特務, ID: 9008
# Movie: 巧虎電影：英雄遊樂園, ID: 10429
# Movie: 青春催落去, ID: 10404
# Movie: 絕地戰警FOR LIFE, ID: 10242
# Movie: 星星知我心, ID: 10409
# Movie: 逃出天堂島, ID: 10384
# Movie: 別告訴她, ID: 10382
# Movie: 真愛裁會贏, ID: 10362
# Movie: 潛艦追緝, ID: 10333
# Movie: 霹靂嬌娃, ID: 10124
# Movie: CATS貓, ID: 10166
# Movie: STAR WARS : 天行者的崛起, ID: 10225
# Movie: 黑色聖誕節, ID: 10291
# Movie: 去年聖誕節, ID: 10256
# Movie: 野蠻遊戲：全面晉級, ID: 10134
# Movie: 寂寞診療室, ID: 10282
# Movie: 布魯克林孤兒, ID: 10224
# Movie: 賽道狂人, ID: 10097
# Movie: 冰雪奇緣2, ID: 9597
# Movie: 萬萬沒想到, ID: 10281
# Movie: 救火奶爸, ID: 10164
# Movie: 決戰中途島, ID: 10130
# Movie: 魔鬼終結者：黑暗宿命, ID: 10067
# Movie: 絕鯊47：猛鯊出籠, ID: 10214
# Movie: 貓咪知道但是貓咪不說, ID: 10203
# Movie: 天氣之子, ID: 10091
# Movie: 寄生上流, ID: 10020
# Movie: 一首搖滾上月球, ID: 4887
# Movie: 錢不夠用2, ID: 3026

# %% [markdown]
# ### 指定你有興趣的電影其ID，然後查詢其放映地區資訊。

# %%
# 參考前一個步驟中擷取到的ID資訊，並指定ID
movie_id = 10518

# %%
url = 'https://movies.yahoo.com.tw/api/v1/areas_by_movie_theater'
payload = {'movie_id':str(movie_id)}

# 模擬一個header
headers = {
    'authority': 'movies.yahoo.com.tw',
    'method': 'GET',
    'path': '/api/v1/areas_by_movie_theater?movie_id=' + str(movie_id),
    'scheme': 'https',
    'accept': 'application/json, text/javascript, */*; q=0.01',
    'accept-encoding': 'gzip, deflate, br',
    'accept-language': 'zh-TW,zh;q=0.9,en-US;q=0.8,en;q=0.7,zh-CN;q=0.6',
    'cookie': 'rxx=9s3x2fws06.1g16irnc&v=1; _ga=GA1.3.2056742944.1551651301; GUC=AQEBAQFczFpdm0IfmwSB&s=AQAAACoo4N5D&g=XMsVBw; BX=4hkdk1decm57t&b=3&s=mr; _ga=GA1.4.2056742944.1551651301; nexagesuid=82843256dd234e8e91aa73f2062f8218; browsed_movie=; avi=eyJpdiI6Im1NeWFJRlVRWDR1endEcGRGUGJUbVE9PSIsInZhbHVlIjoickRpU3JuUytmcGl6cjF5OW0rNU9iZz09IiwibWFjIjoiY2VmY2NkNzZmM2NhNjY5YzlkOTcyNjE5OGEyMzU0NWYxOTdmMDRkMDY3OWNmMmZjOTMxYjc5MjI5N2Q5NGE5MiJ9; cmp=t=1559391030&j=0; _gid=GA1.4.779543841.1559391031; XSRF-TOKEN=%3D; m_s=; _gat=1; nexagesd=10',
    'dnt': '1',
    'mv-authorization': '21835b082e15b91a69b3851eec7b31b82ce82afb',
    'referer': 'https://movies.yahoo.com.tw/',
    'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/74.0.3729.169 Safari/537.36',
    'x-requested-with': 'XMLHttpRequest',
}
    
resp = requests.get(url, params=payload, headers=headers)
#print(resp.json())  # 若有需要，列印出json原始碼

# 這裡回傳的格式是JSON格式的資料，要解析JSON擷取資料
for p in resp.json():
    print('放映地區: {0}, 代號(area_id): {1}'.format(p['title'], p['area_id']))
# Out:
# 放映地區: 台北市, 代號(area_id): 28
# 放映地區: 新北市, 代號(area_id): 8
# 放映地區: 桃園, 代號(area_id): 16
# 放映地區: 新竹, 代號(area_id): 20
# 放映地區: 台中, 代號(area_id): 2
# 放映地區: 台南, 代號(area_id): 10
# 放映地區: 高雄, 代號(area_id): 17

# %% [markdown]
# ### 指定你想要觀看的放映地區，查詢有上映電影的場次日期

# %%
# 指定放映地區
area_id = 28

# %%
# 向網站發送請求
url = 'https://movies.yahoo.com.tw/movietime_result.html'
payload = {'movie_id':str(movie_id), 'area_id':str(area_id)}
resp = requests.get(url, params=payload)
resp.encoding = 'utf-8'

soup = BeautifulSoup(resp.text, 'lxml')
movie_date = soup.find_all("label", attrs={'for':re.compile("date_[\d]")})

# 列印播放日期
for date in movie_date:
    print("%s %s" % (date.p.string, date.h3.string))
# Out:
# 三月 16
# 三月 17
# 三月 18
# 三月 19
# 三月 20

# %% [markdown]
# ### 最後指定觀看的日期，查詢並列印出放映的電影院、放映類型(數位、3D、IMAX 3D...)、放映時間等資訊。

# %%
# 選定要觀看的日期
date = "2020-03-16"

# %%
# 向網站發送請求，獲取上映的電影院及時間資訊
url = "https://movies.yahoo.com.tw/ajax/pc/get_schedule_by_movie"
payload = {'movie_id':str(movie_id),
           'date':date,
           'area_id':str(area_id),
           'theater_id':'',
           'datetime':'',
           'movie_type_id':''}

resp = requests.get(url, params=payload)
#print(resp.json()['view'])  # 若有需要，列印出json原始碼

soup = BeautifulSoup(resp.json()['view'], 'lxml')
html = soup.find_all("ul", attrs={'data-theater_name':re.compile(".*")})

# %%
print(html)
# Out:
# [<ul class="area_time _c jq_area_time" data-theater_name="國賓影城(台北長春廣場)" data-theater_schedules="https://movies.yahoo.com.tw/theater_result.html/id=29" data-theater_url="http://www.ambassador.com.tw/" id="theater_id_29">
# <li class="adds">
# <a href="https://movies.yahoo.com.tw/theater_result.html/id=29">國賓影城(台北長春廣場)</a>
# <span>02-25155755</span>
# </li>
# <li class="taps">
# <span class="tapR">數位</span> </li>
# <li class="time _c">
# <div class="input_picker jq_input_picker">
# <input class="gabtn" data-ga="['電影頁_時刻表', '電影頁_時刻表_場次', '刺激1995']" data-movie_date="03.16" data-movie_time="11:10" data-movie_title="刺激1995" data-movie_type="數位" data-news="news" id="73348207" name="schedule_list" type="radio" value="2020-03-16 11:10:00"/>
# <label class="select" for="73348207">11:10</label>
# <input class="gabtn" data-ga="['電影頁_時刻表', '電影頁_時刻表_場次', '刺激1995']" data-movie_date="03.16" data-movie_time="13:45" data-movie_title="刺激1995" data-movie_type="數位" data-news="news" id="73348208" name="schedule_list" type="radio" value="2020-03-16 13:45:00"/>
# <label class="select" for="73348208">13:45</label>
# <input class="gabtn" data-ga="['電影頁_時刻表', '電影頁_時刻表_場次', '刺激1995']" data-movie_date="03.16" data-movie_time="16:20" data-movie_title="刺激1995" data-movie_type="數位" data-news="news" id="73348209" name="schedule_list" type="radio" value="2020-03-16 16:20:00"/>
# <label class="select" for="73348209">16:20</label>
# <input class="gabtn" data-ga="['電影頁_時刻表', '電影頁_時刻表_場次', '刺激1995']" data-movie_date="03.16" data-movie_time="19:00" data-movie_title="刺激1995" data-movie_type="數位" data-news="news" id="73348210" name="schedule_list" type="radio" value="2020-03-16 19:00:00"/>
# <label class="select" for="73348210">19:00</label>
# </div>
# </li>
# </ul>, <ul class="area_time _c jq_area_time" data-theater_name="台北美麗華大直影城" data-theater_schedules="https://movies.yahoo.com.tw/theater_result.html/id=32" data-theater_url="http://www.miramarcinemas.tw/" id="theater_id_32">
# <li class="adds">
# <a href="https://movies.yahoo.com.tw/theater_result.html/id=32">台北美麗華大直影城</a>
# <span>02-85022208</span>
# </li>
# <li class="taps">
# <span class="tapR">數位</span> </li>
# <li class="time _c">
# <div class="input_picker jq_input_picker">
# <input class="gabtn" data-cinema="40288eb0050f31210ada0f55676b1bbc" data-date="1584288000" data-ezding="ezding" data-ga="['電影頁_時刻表', '電影頁_時刻表_場次', '刺激1995']" data-movie="619aee3f9b974a27b68bb16b2a290b8b" data-movie_date="03.16" data-movie_time="14:00" data-movie_title="刺激1995" data-movie_type="數位" data-session="b36dca6180e5497d8e20c695ba4bd0f3" data-time="1584338400" id="73320966" name="schedule_list" type="radio" value="2020-03-16 14:00:00"/>
# <label class="select" for="73320966">14:00</label>
# <input class="gabtn" data-cinema="40288eb0050f31210ada0f55676b1bbc" data-date="1584288000" data-ezding="ezding" data-ga="['電影頁_時刻表', '電影頁_時刻表_場次', '刺激1995']" data-movie="619aee3f9b974a27b68bb16b2a290b8b" data-movie_date="03.16" data-movie_time="18:30" data-movie_title="刺激1995" data-movie_type="數位" data-session="321edeb2ceb84527931db091b73fb7cd" data-time="1584354600" id="73320967" name="schedule_list" type="radio" value="2020-03-16 18:30:00"/>
# <label class="select" for="73320967">18:30</label>
# </div>
# </li>
# </ul>, <ul class="area_time _c jq_area_time" data-theater_name="國賓大戲院(西門)" data-theater_schedules="https://movies.yahoo.com.tw/theater_result.html/id=37" data-theater_url="http://www.ambassador.com.tw/" id="theater_id_37">
# <li class="adds">
# <a href="https://movies.yahoo.com.tw/theater_result.html/id=37">國賓大戲院(西門)</a>
# <span>02-23611222</span>
# </li>
# <li class="taps">
# <span class="tapR">數位</span> </li>
# <li class="time _c">
# <div class="input_picker jq_input_picker">
# <input class="gabtn" data-ga="['電影頁_時刻表', '電影頁_時刻表_場次', '刺激1995']" data-movie_date="03.16" data-movie_time="14:10" data-movie_title="刺激1995" data-movie_type="數位" data-news="news" id="73348068" name="schedule_list" type="radio" value="2020-03-16 14:10:00"/>
# <label class="select" for="73348068">14:10</label>
# <input class="gabtn" data-ga="['電影頁_時刻表', '電影頁_時刻表_場次', '刺激1995']" data-movie_date="03.16" data-movie_time="16:30" data-movie_title="刺激1995" data-movie_type="數位" data-news="news" id="73348069" name="schedule_list" type="radio" value="2020-03-16 16:30:00"/>
# <label class="select" for="73348069">16:30</label>
# <input class="gabtn" data-ga="['電影頁_時刻表', '電影頁_時刻表_場次', '刺激1995']" data-movie_date="03.16" data-movie_time="20:30" data-movie_title="刺激1995" data-movie_type="數位" data-news="news" id="73348070" name="schedule_list" type="radio" value="2020-03-16 20:30:00"/>
# <label class="select" for="73348070">20:30</label>
# </div>
# </li>
# </ul>, <ul class="area_time _c jq_area_time" data-theater_name="台北信義威秀影城" data-theater_schedules="https://movies.yahoo.com.tw/theater_result.html/id=45" data-theater_url="http://www.vscinemas.com.tw/" id="theater_id_45">
# <li class="adds">
# <a href="https://movies.yahoo.com.tw/theater_result.html/id=45">台北信義威秀影城</a>
# <span>02-87805566</span>
# </li>
# <li class="taps">
# <span class="tapR">數位</span> </li>
# <li class="time _c">
# <div class="input_picker jq_input_picker">
# <input class="gabtn" data-cinema="40288eb0050f542401050f554e7e0674" data-date="1584288000" data-ezding="ezding" data-ga="['電影頁_時刻表', '電影頁_時刻表_場次', '刺激1995']" data-movie="ea1b52a220ff44e5910aa21a20765a93" data-movie_date="03.16" data-movie_time="10:35" data-movie_title="刺激1995" data-movie_type="數位" data-session="dbaf256ee5eb4980987267998ff7c0b8" data-time="1584326100" id="73331606" name="schedule_list" type="radio" value="2020-03-16 10:35:00"/>
# <label class="select" for="73331606">10:35</label>
# <input class="gabtn" data-cinema="40288eb0050f542401050f554e7e0674" data-date="1584288000" data-ezding="ezding" data-ga="['電影頁_時刻表', '電影頁_時刻表_場次', '刺激1995']" data-movie="ea1b52a220ff44e5910aa21a20765a93" data-movie_date="03.16" data-movie_time="14:30" data-movie_title="刺激1995" data-movie_type="數位" data-session="14a311f4b96548a4b96f1ac47c413924" data-time="1584340200" id="73331607" name="schedule_list" type="radio" value="2020-03-16 14:30:00"/>
# <label class="select" for="73331607">14:30</label>
# <input class="gabtn" data-cinema="40288eb0050f542401050f554e7e0674" data-date="1584288000" data-ezding="ezding" data-ga="['電影頁_時刻表', '電影頁_時刻表_場次', '刺激1995']" data-movie="ea1b52a220ff44e5910aa21a20765a93" data-movie_date="03.16" data-movie_time="17:10" data-movie_title="刺激1995" data-movie_type="數位" data-session="afe049818e164c6f90ebd7a2c0190321" data-time="1584349800" id="73331608" name="schedule_list" type="radio" value="2020-03-16 17:10:00"/>
# <label class="select" for="73331608">17:10</label>
# <input class="gabtn" data-cinema="40288eb0050f542401050f554e7e0674" data-date="1584288000" data-ezding="ezding" data-ga="['電影頁_時刻表', '電影頁_時刻表_場次', '刺激1995']" data-movie="ea1b52a220ff44e5910aa21a20765a93" data-movie_date="03.16" data-movie_time="19:50" data-movie_title="刺激1995" data-movie_type="數位" data-session="96f6a9bd3a9843208ce7a3385a991d3d" data-time="1584359400" id="73331609" name="schedule_list" type="radio" value="2020-03-16 19:50:00"/>
# <label class="select" for="73331609">19:50</label>
# <input class="gabtn" data-cinema="40288eb0050f542401050f554e7e0674" data-date="1584288000" data-ezding="ezding" data-ga="['電影頁_時刻表', '電影頁_時刻表_場次', '刺激1995']" data-movie="ea1b52a220ff44e5910aa21a20765a93" data-movie_date="03.16" data-movie_time="22:30" data-movie_title="刺激1995" data-movie_type="數位" data-session="500896c9cb3a40ee8b8d6f8c32d1d75d" data-time="1584369000" id="73331610" name="schedule_list" type="radio" value="2020-03-16 22:30:00"/>
# <label class="select" for="73331610">22:30</label>
# </div>
# </li>
# </ul>, <ul class="area_time _c jq_area_time" data-theater_name="光點華山電影館" data-theater_schedules="https://movies.yahoo.com.tw/theater_result.html/id=152" data-theater_url="http://www.spot-hs.org.tw/" id="theater_id_152">
# <li class="adds">
# <a href="https://movies.yahoo.com.tw/theater_result.html/id=152">光點華山電影館</a>
# <span>02-23940622</span>
# </li>
# <li class="taps">
# <span class="tapR">數位</span> </li>
# <li class="time _c">
# <div class="input_picker jq_input_picker">
# <input class="gabtn" data-ga="['電影頁_時刻表', '電影頁_時刻表_場次', '刺激1995']" data-movie_date="03.16" data-movie_time="14:30" data-movie_title="刺激1995" data-movie_type="數位" data-news="news" id="73349762" name="schedule_list" type="radio" value="2020-03-16 14:30:00"/>
# <label class="select" for="73349762">14:30</label>
# <input class="gabtn" data-ga="['電影頁_時刻表', '電影頁_時刻表_場次', '刺激1995']" data-movie_date="03.16" data-movie_time="20:40" data-movie_title="刺激1995" data-movie_type="數位" data-news="news" id="73349763" name="schedule_list" type="radio" value="2020-03-16 20:40:00"/>
# <label class="select" for="73349763">20:40</label>
# </div>
# </li>
# </ul>, <ul class="area_time _c jq_area_time" data-theater_name="誠品電影院" data-theater_schedules="https://movies.yahoo.com.tw/theater_result.html/id=168" data-theater_url="https://meet.eslite.com/tw/tc/gallery/201803020001" id="theater_id_168">
# <li class="adds">
# <a href="https://movies.yahoo.com.tw/theater_result.html/id=168">誠品電影院</a>
# <span>02-66365888</span>
# </li>
# <li class="taps">
# <span class="tapR">數位</span> </li>
# <li class="time _c">
# <div class="input_picker jq_input_picker">
# <input class="gabtn" data-ga="['電影頁_時刻表', '電影頁_時刻表_場次', '刺激1995']" data-movie_date="03.16" data-movie_time="13:40" data-movie_title="刺激1995" data-movie_type="數位" data-news="news" id="73349880" name="schedule_list" type="radio" value="2020-03-16 13:40:00"/>
# <label class="select" for="73349880">13:40</label>
# <input class="gabtn" data-ga="['電影頁_時刻表', '電影頁_時刻表_場次', '刺激1995']" data-movie_date="03.16" data-movie_time="16:30" data-movie_title="刺激1995" data-movie_type="數位" data-news="news" id="73349881" name="schedule_list" type="radio" value="2020-03-16 16:30:00"/>
# <label class="select" for="73349881">16:30</label>
# </div>
# </li>
# </ul>, <ul class="area_time _c jq_area_time" data-theater_name="喜樂時代影城南港店" data-theater_schedules="https://movies.yahoo.com.tw/theater_result.html/id=186" data-theater_url="http://www.centuryasia.com.tw/default.aspx" id="theater_id_186">
# <li class="adds">
# <a href="https://movies.yahoo.com.tw/theater_result.html/id=186">喜樂時代影城南港店</a>
# <span>02-27888185</span>
# </li>
# <li class="taps">
# <span class="tapR">數位</span> </li>
# <li class="time _c">
# <div class="input_picker jq_input_picker">
# <input class="gabtn" data-cinema="40288eb0050f542401050f5681782dc5" data-date="1584288000" data-ezding="ezding" data-ga="['電影頁_時刻表', '電影頁_時刻表_場次', '刺激1995']" data-movie="669c42ca35004b24a0506b628e3ddba8" data-movie_date="03.16" data-movie_time="11:00" data-movie_title="刺激1995" data-movie_type="數位" data-session="8b6a2a81da5b46c9bd59a3f8d124489e" data-time="1584327600" id="73335665" name="schedule_list" type="radio" value="2020-03-16 11:00:00"/>
# <label class="select" for="73335665">11:00</label>
# <input class="gabtn" data-cinema="40288eb0050f542401050f5681782dc5" data-date="1584288000" data-ezding="ezding" data-ga="['電影頁_時刻表', '電影頁_時刻表_場次', '刺激1995']" data-movie="669c42ca35004b24a0506b628e3ddba8" data-movie_date="03.16" data-movie_time="15:30" data-movie_title="刺激1995" data-movie_type="數位" data-session="30d9832ab572410985b744dfcad71645" data-time="1584343800" id="73335666" name="schedule_list" type="radio" value="2020-03-16 15:30:00"/>
# <label class="select" for="73335666">15:30</label>
# <input class="gabtn" data-cinema="40288eb0050f542401050f5681782dc5" data-date="1584288000" data-ezding="ezding" data-ga="['電影頁_時刻表', '電影頁_時刻表_場次', '刺激1995']" data-movie="669c42ca35004b24a0506b628e3ddba8" data-movie_date="03.16" data-movie_time="20:00" data-movie_title="刺激1995" data-movie_type="數位" data-session="f4eff5d2e00245518523b575c328f4ad" data-time="1584360000" id="73335667" name="schedule_list" type="radio" value="2020-03-16 20:00:00"/>
# <label class="select" for="73335667">20:00</label>
# <input class="gabtn" data-cinema="40288eb0050f542401050f5681782dc5" data-date="1584288000" data-ezding="ezding" data-ga="['電影頁_時刻表', '電影頁_時刻表_場次', '刺激1995']" data-movie="669c42ca35004b24a0506b628e3ddba8" data-movie_date="03.16" data-movie_time="22:40" data-movie_title="刺激1995" data-movie_type="數位" data-session="2045baa4e5804840b0f6e2da924deb57" data-time="1584369600" id="73335668" name="schedule_list" type="radio" value="2020-03-16 22:40:00"/>
# <label class="select" for="73335668">22:40</label>
# </div>
# </li>
# </ul>, <ul class="area_time _c jq_area_time" data-theater_name="MUVIE CINEMAS台北松仁威秀" data-theater_schedules="https://movies.yahoo.com.tw/theater_result.html/id=254" data-theater_url="https://www.vscinemas.com.tw/vsweb/theater/detail2.aspx?id=23" id="theater_id_254">
# <li class="adds">
# <a href="https://movies.yahoo.com.tw/theater_result.html/id=254">MUVIE CINEMAS台北松仁威秀</a>
# <span>(02)8780-0800</span>
# </li>
# <li class="taps">
# <span class="tapR">TITAN</span> </li>
# <li class="time _c">
# <div class="input_picker jq_input_picker">
# <input class="gabtn" data-cinema="470e99e70b5611eaa91e06ba2bcebcfa" data-date="1584288000" data-ezding="ezding" data-ga="['電影頁_時刻表', '電影頁_時刻表_場次', '刺激1995']" data-movie="6e62d9970c7b4eeb8a2ff12c7700350d" data-movie_date="03.16" data-movie_time="13:20" data-movie_title="刺激1995" data-movie_type="TITAN" data-session="715710bace1b42ba984fe6dd76a05fb5" data-time="1584336000" id="73336116" name="schedule_list" type="radio" value="2020-03-16 13:20:00"/>
# <label class="select" for="73336116">13:20</label>
# </div>
# </li>
# </ul>]

# %%
for data in html:
    print('電影院:',data.find('a').text)
    
    print('放映類型:',data.find(class_='tapR').text)
    
    for x in range(1,10):
        try:
            print(data.find_all(class_='gabtn')[x]['value'])
        except:
            pass
    
    print('---------------------------------')
# Out:
# 電影院: 國賓影城(台北長春廣場)
# 放映類型: 數位
# 2020-03-16 13:45:00
# 2020-03-16 16:20:00
# 2020-03-16 19:00:00
# ---------------------------------
# 電影院: 台北美麗華大直影城
# 放映類型: 數位
# 2020-03-16 18:30:00
# ---------------------------------
# 電影院: 國賓大戲院(西門)
# 放映類型: 數位
# 2020-03-16 16:30:00
# 2020-03-16 20:30:00
# ---------------------------------
# 電影院: 台北信義威秀影城
# 放映類型: 數位
# 2020-03-16 14:30:00
# 2020-03-16 17:10:00
# 2020-03-16 19:50:00
# 2020-03-16 22:30:00
# ---------------------------------
# 電影院: 光點華山電影館
# 放映類型: 數位
# 2020-03-16 20:40:00
# ---------------------------------
# 電影院: 誠品電影院
# 放映類型: 數位
# 2020-03-16 16:30:00
# ---------------------------------
# 電影院: 喜樂時代影城南港店
# 放映類型: 數位
# 2020-03-16 15:30:00
# 2020-03-16 20:00:00
# 2020-03-16 22:40:00
# ---------------------------------
# 電影院: MUVIE CINEMAS台北松仁威秀
# 放映類型: TITAN
# ---------------------------------

# %%
# Out:
# ----------------------------------------------------------------------
# 電影院:  台北美麗華大直影城
# 放映類型:  數位
# 2019-08-21 09:00:00
# 2019-08-21 11:10:00
# 2019-08-21 13:15:00
# 2019-08-21 15:20:00
# 2019-08-21 19:30:00
# 2019-08-21 21:40:00
# 2019-08-21 22:30:00
# ----------------------------------------------------------------------
# 電影院:  台北新光影城
# 放映類型:  數位
# 2019-08-21 10:00:00
# 2019-08-21 14:50:00
# 2019-08-21 19:30:00
# ----------------------------------------------------------------------
# 電影院:  台北in89豪華數位影城
# 放映類型:  數位
# 2019-08-21 09:30:00
# 2019-08-21 11:20:00
# 2019-08-21 13:15:00
# 2019-08-21 15:10:00
# 2019-08-21 16:10:00
# 2019-08-21 17:10:00
# 2019-08-21 18:05:00
# 2019-08-21 19:10:00
# 2019-08-21 21:10:00
# 2019-08-21 23:10:00
# 2019-08-22 01:10:00
# ----------------------------------------------------------------------
# 電影院:  台北日新威秀影城
# 放映類型:  數位
# 2019-08-21 09:00:00
# 2019-08-21 10:55:00
# 2019-08-21 12:50:00
# 2019-08-21 14:45:00
# 2019-08-21 16:40:00
# 2019-08-21 18:35:00
# 2019-08-21 20:35:00
# ----------------------------------------------------------------------
# 電影院:  喜滿客絕色影城
# 放映類型:  數位
# 2019-08-21 10:00:00
# 2019-08-21 11:55:00
# 2019-08-21 13:50:00
# 2019-08-21 15:45:00
# 2019-08-21 17:40:00
# 2019-08-21 19:35:00
# 2019-08-21 21:30:00
# ----------------------------------------------------------------------
# 電影院:  台北信義威秀影城
# 放映類型:  數位
# 2019-08-21 09:00:00
# 2019-08-21 11:00:00
# 2019-08-21 13:00:00
# 2019-08-21 15:00:00
# 2019-08-21 17:00:00
# 2019-08-21 19:00:00
# 2019-08-21 21:00:00
# 2019-08-21 23:00:00
# ----------------------------------------------------------------------
# 電影院:  喜滿客京華影城
# 放映類型:  數位
# 2019-08-21 10:30:00
# 2019-08-21 12:30:00
# 2019-08-21 14:30:00
# 2019-08-21 16:30:00
# 2019-08-21 18:30:00
# 2019-08-21 20:30:00
# 2019-08-21 22:30:00
# ----------------------------------------------------------------------
# 電影院:  京站威秀影城
# 放映類型:  數位
# 2019-08-21 09:00:00
# 2019-08-21 11:00:00
# 2019-08-21 13:00:00
# 2019-08-21 15:00:00
# 2019-08-21 17:00:00
# 2019-08-21 19:00:00
# 2019-08-21 21:00:00
# ----------------------------------------------------------------------
# 電影院:  喜樂時代影城南港店
# 放映類型:  數位
# 2019-08-21 10:20:00
# 2019-08-21 11:10:00
# 2019-08-21 12:20:00
# 2019-08-21 13:10:00
# 2019-08-21 14:20:00
# 2019-08-21 15:10:00
# 2019-08-21 16:20:00
# 2019-08-21 17:10:00
# 2019-08-21 18:20:00
# 2019-08-21 19:15:00
# 2019-08-21 20:20:00
# 2019-08-21 21:15:00
# 2019-08-21 22:20:00
