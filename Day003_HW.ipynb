# %% [markdown]
# # Python 下載XML檔案與解析
#
#
# * 了解 xml 檔案格式與內容
# * 能夠利用套件存取 xml 格式的檔案

# %% [markdown]
# ## 作業目標
#
# * 比較一下範例檔案中的「File I/O」與「xmltodict」讀出來的內容有什麼差異
#
# * 根據範例檔案的結果：
#     1. 請問高雄市有多少地區有溫度資料？
#     2. 請取出每一個地區所記錄的第一個時間點跟溫度
#     3. 請取出第一個地區所記錄的每一個時間點跟溫度

# %% [markdown]
# ### 比較一下範例檔案中的「File I/O」與「xmltodict」讀出來的內容有什麼差異

# %% [markdown]
# 前者讀出完整的xml檔，後者可擷取我們需要的文字內容。

# %% [markdown]
# ### 根據範例檔案的結果：
#
# 1. 請問高雄市有多少地區有溫度資料？
# 2. 請取出每一個地區所記錄的第一個時間點跟溫度
# 3. 請取出第一個地區所記錄的每一個時間點跟溫度

# %%
import urllib.request
import zipfile

res = "http://opendata.cwb.gov.tw/govdownload?dataid=F-D0047-093&authorizationkey=rdec-key-123-45678-011121314"
urllib.request.urlretrieve(res, "./data/D3_data/D3.zip")
f = zipfile.ZipFile('./data/D3_data/D3.zip')
f.extractall('./data/D3_data')

# %%
# 1. 請問高雄市有多少地區有溫度資料？

import xmltodict

with open('./data/D3_data/64_72hr_CH.xml') as fd:
    doc = dict(xmltodict.parse(fd.read()))

data = doc['cwbopendata']['dataset']['locations']['location']
print('Ans:有',len(data),'個地區有溫度資料')
# Out:
# Ans:有 38 個地區有溫度資料

# %%
# 2. 請取出每一個地區所記錄的第一個時間點跟溫度

for location in data:
    print(location['locationName'])
    
    print(location['weatherElement'][0]['time'][0]['dataTime'])
    
    A = location['weatherElement'][0]['time'][0]['elementValue']['value']
    B = location['weatherElement'][0]['time'][0]['elementValue']['measures']
    print(A+B)
# Out:
# 鹽埕區
# 2020-02-24T18:00:00+08:00
# 24攝氏度
# 鼓山區
# 2020-02-24T18:00:00+08:00
# 24攝氏度
# 左營區
# 2020-02-24T18:00:00+08:00
# 24攝氏度
# 楠梓區
# 2020-02-24T18:00:00+08:00
# 24攝氏度
# 三民區
# 2020-02-24T18:00:00+08:00
# 24攝氏度
# 新興區
# 2020-02-24T18:00:00+08:00
# 25攝氏度
# 前金區
# 2020-02-24T18:00:00+08:00
# 24攝氏度
# 苓雅區
# 2020-02-24T18:00:00+08:00
# 25攝氏度
# 前鎮區
# 2020-02-24T18:00:00+08:00
# 25攝氏度
# 旗津區
# 2020-02-24T18:00:00+08:00
# 24攝氏度
# 小港區
# 2020-02-24T18:00:00+08:00
# 25攝氏度
# 鳳山區
# 2020-02-24T18:00:00+08:00
# 25攝氏度
# 林園區
# 2020-02-24T18:00:00+08:00
# 25攝氏度
# 大寮區
# 2020-02-24T18:00:00+08:00
# 25攝氏度
# 大樹區
# 2020-02-24T18:00:00+08:00
# 25攝氏度
# 大社區
# 2020-02-24T18:00:00+08:00
# 24攝氏度
# 仁武區
# 2020-02-24T18:00:00+08:00
# 24攝氏度
# 鳥松區
# 2020-02-24T18:00:00+08:00
# 25攝氏度
# 岡山區
# 2020-02-24T18:00:00+08:00
# 24攝氏度
# 橋頭區
# 2020-02-24T18:00:00+08:00
# 25攝氏度
# 燕巢區
# 2020-02-24T18:00:00+08:00
# 24攝氏度
# 田寮區
# 2020-02-24T18:00:00+08:00
# 23攝氏度
# 阿蓮區
# 2020-02-24T18:00:00+08:00
# 23攝氏度
# 路竹區
# 2020-02-24T18:00:00+08:00
# ...

# %%
# 3. 請取出第一個地區所記錄的每一個時間點跟溫度

print(data[0]['locationName'])

for element in data:
    print(data[0]['weatherElement'][0]['time'][0]['dataTime'])
    
    C = data[0]['weatherElement'][0]['time'][0]['elementValue']['value']
    D = data[0]['weatherElement'][0]['time'][0]['elementValue']['measures']
    print(C+D)
# Out:
# 鹽埕區
# 2020-02-24T18:00:00+08:00
# 24攝氏度
# 2020-02-24T18:00:00+08:00
# 24攝氏度
# 2020-02-24T18:00:00+08:00
# 24攝氏度
# 2020-02-24T18:00:00+08:00
# 24攝氏度
# 2020-02-24T18:00:00+08:00
# 24攝氏度
# 2020-02-24T18:00:00+08:00
# 24攝氏度
# 2020-02-24T18:00:00+08:00
# 24攝氏度
# 2020-02-24T18:00:00+08:00
# 24攝氏度
# 2020-02-24T18:00:00+08:00
# 24攝氏度
# 2020-02-24T18:00:00+08:00
# 24攝氏度
# 2020-02-24T18:00:00+08:00
# 24攝氏度
# 2020-02-24T18:00:00+08:00
# 24攝氏度
# 2020-02-24T18:00:00+08:00
# 24攝氏度
# 2020-02-24T18:00:00+08:00
# 24攝氏度
# 2020-02-24T18:00:00+08:00
# 24攝氏度
# 2020-02-24T18:00:00+08:00
# 24攝氏度
# 2020-02-24T18:00:00+08:00
# 24攝氏度
# 2020-02-24T18:00:00+08:00
# 24攝氏度
# 2020-02-24T18:00:00+08:00
# 24攝氏度
# 2020-02-24T18:00:00+08:00
# 24攝氏度
# 2020-02-24T18:00:00+08:00
# 24攝氏度
# 2020-02-24T18:00:00+08:00
# 24攝氏度
# 2020-02-24T18:00:00+08:00
# 24攝氏度
# 2020-02-24T18:00:00+08:00
# 24攝氏度
# 2020-02-24T18:00:00+08:00
# 24攝氏度
# 2020-02-24T18:00:00+08:00
# 24攝氏度
# 2020-02-24T18:00:00+08:00
# 24攝氏度
# ...
