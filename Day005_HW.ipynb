# %% [markdown]
# # API 資料串接 - 以 Dcard API 實作範例
#
# * 了解 Dcard API 使用方式與回傳內容
# * 撰寫程式存取 API 且解析 JSON 格式資料

# %% [markdown]
# ## 作業目標
#
# * 請利用 API: https://www.dcard.tw/_api/forums/pet/posts?popular=true 回答下列問題：
#
# 1. 這個 API 一次會回傳幾筆資料？每一筆資料包含哪些欄位？
# 2. 取出每一筆資料的「標題」、「貼文時間」、「留言人數」、「按讚人數」
# 3. 計算熱門/非熱門文章的「平均留言人數」與「平均按讚人數」

# %%
#熱門文章
import requests,json

r1 = requests.get('https://www.dcard.tw/_api/forums/pet/posts?popular=true')
response1 = r1.text
json.loads(response1)
# Out:
# [{'id': 233147249,
#   'title': '有人有看過這麼有喜感的貓嗎',
#   'excerpt': '我家的貓天生帶有喜感，有些照片都可以做成貼圖來賣了，像極了清末在鴉片館的癮君子，又像是坦腹東床的王羲之 再躺也沒有人來相親啦，這三張拉近一看，你是在公三小 我的罐罐你拿去吃掉了？笑死人 聽你在歐北共，',
#   'anonymousSchool': False,
#   'anonymousDepartment': True,
#   'pinned': False,
#   'forumId': '7ee21581-1307-4ba9-b9dc-82028bdcca49',
#   'replyId': None,
#   'createdAt': '2020-02-27T00:41:45.740Z',
#   'updatedAt': '2020-02-27T02:12:02.293Z',
#   'commentCount': 61,
#   'likeCount': 1431,
#   'withNickname': False,
#   'tags': [],
#   'topics': ['貓', '米克斯', '貓咪'],
#   'meta': {'layout': 'classic'},
#   'forumName': '寵物',
#   'forumAlias': 'pet',
#   'gender': 'M',
#   'school': '國立政治大學',
#   'replyTitle': None,
#   'mediaMeta': [{'id': '6be5d281-2419-4f71-aa52-2f7710ca8392',
#     'url': 'https://i.imgur.com/xeJu68Il.jpg',
#     'normalizedUrl': 'https://i.imgur.com/xeJu68Il.jpg',
#     'thumbnail': 'https://i.imgur.com/xeJu68Il.jpg',
#     'type': 'image/thumbnail',
#     'tags': ['ANNOTATED'],
# ...

# %%
#非熱門文章

r2 = requests.get('https://www.dcard.tw/_api/forums/pet/posts?popular=false')
response2 = r2.text
json.loads(response2)
# Out:
# [{'id': 233154752,
#   'title': '戲精貓-瞳孔放大片篇',
#   'excerpt': '小笨貓似乎非常喜歡戴瞳孔放大片，無論是在紙袋裡，或者趴著休息時，或是自拍的時候，或是看著我的時候，甚至在洗澡的時候，都不會拔掉呢！，小笨貓的IGlumi_0728',
#   'anonymousSchool': False,
#   'anonymousDepartment': False,
#   'pinned': False,
#   'forumId': '7ee21581-1307-4ba9-b9dc-82028bdcca49',
#   'replyId': None,
#   'createdAt': '2020-02-28T05:13:43.720Z',
#   'updatedAt': '2020-02-28T05:13:43.720Z',
#   'commentCount': 0,
#   'likeCount': 1,
#   'withNickname': True,
#   'tags': [],
#   'topics': ['戲精', '貓', '寵物', '可愛', '領養代替購買'],
#   'meta': {'layout': 'classic'},
#   'forumName': '寵物',
#   'forumAlias': 'pet',
#   'gender': 'F',
#   'school': '吃不不吃吐司',
#   'department': 'hdyy',
#   'replyTitle': None,
#   'reportReason': '',
#   'mediaMeta': [{'id': '211044b8-286d-48d7-aba8-3a8e497f107a',
#     'url': 'https://i.imgur.com/vmihryDl.jpg',
#     'normalizedUrl': 'https://i.imgur.com/vmihryDl.jpg',
#     'thumbnail': 'https://i.imgur.com/vmihryDl.jpg',
#     'type': 'image/thumbnail',
# ...

# %%
# 1. 這個 API 一次會回傳幾筆資料？每一筆資料包含哪些欄位？

data1 = json.loads(response1)

sum = 0
for info in data1:
    info['title']
    sum+=1
print('Ans1:一次回傳',sum,'筆資料')
print(info.keys())
# Out:
# Ans1:一次回傳 30 筆資料
# dict_keys(['id', 'title', 'excerpt', 'anonymousSchool', 'anonymousDepartment', 'pinned', 'forumId', 'replyId', 'createdAt', 'updatedAt', 'commentCount', 'likeCount', 'withNickname', 'tags', 'topics', 'meta', 'forumName', 'forumAlias', 'gender', 'school', 'replyTitle', 'mediaMeta', 'reactions', 'hidden', 'customStyle', 'isSuspiciousAccount', 'layout', 'withImages', 'withVideos', 'media', 'reportReasonText', 'postAvatar'])

# %%
# 2. 取出每一筆資料的「標題」、「貼文時間」、「留言人數」、「按讚人數」

for info in data:
    print(info['title'])
    print(info['createdAt'])
    print('留言人數：',info['commentCount'])
    print('按讚人數：',info['likeCount'])
# Out:
# 有人有看過這麼有喜感的貓嗎
# 2020-02-27T00:41:45.740Z
# 留言人數： 56
# 按讚人數： 1382
# 我的夢幻玉米蛇😭
# 2020-02-26T17:59:21.848Z
# 留言人數： 44
# 按讚人數： 1111
# 你要工人？
# 2020-02-26T18:35:16.716Z
# 留言人數： 9
# 按讚人數： 1080
# 小蝦蝦不知道可不可以上熱門🥺
# 2020-02-26T22:13:53.583Z
# 留言人數： 32
# 按讚人數： 259
# 天氣好想拍貓 天氣不好想拍貓
# 2020-02-26T17:05:42.877Z
# 留言人數： 1
# 按讚人數： 210
# #圖 在公園遛天竺鼠ヽ(✿ﾟ▽ﾟ)ノ
# 2020-02-27T08:00:49.162Z
# 留言人數： 5
# 按讚人數： 69
# 看起來很衰的臘腸狗
# 2020-02-27T03:24:54.078Z
# 留言人數： 6
# 按讚人數： 56
# 不喜歡洗澡的狗
# 2020-02-27T01:06:35.270Z
# 留言人數： 9
# 按讚人數： 29
# 習慣躺枕頭睡覺
# 2020-02-27T05:50:41.877Z
# 留言人數： 6
# 按讚人數： 21
# 拍屁屁奴隸的心聲
# 2020-02-27T13:38:01.565Z
# 留言人數： 2
# 按讚人數： 20
# 柴柴從後面看像什麼！
# 2020-02-26T18:19:46.140Z
# 留言人數： 2
# 按讚人數： 16
# 朕想怎麼睡 就怎麼睡(˶‾᷄ ⁻̫ ‾᷅˵)
# 2020-02-27T19:53:48.404Z
# 留言人數： 0
# 按讚人數： 15
# 來曬一下家裡的黑狗🐶
# 2020-02-27T21:10:15.772Z
# 留言人數： 1
# 按讚人數： 14
# 來曬一下可爾必思
# 2020-02-27T08:19:49.020Z
# 留言人數： 1
# 按讚人數： 12
# 露屁屁外星人
# 2020-02-27T07:09:01.168Z
# 留言人數： 0
# 按讚人數： 12
# 當你家的貓在看風景時⋯
# 2020-02-27T06:48:59.523Z
# 留言人數： 0
# 按讚人數： 12
# ...

# %%
# 3. 計算熱門/非熱門文章的「平均留言人數」與「平均按讚人數」

#熱門文章
count = 0
for info in data:
    info['commentCount']
    count+=info['commentCount']
print('熱門文章平均留言人數：',count/sum)

count = 0
for info in data:
    info['likeCount']
    count+=info['likeCount']
print('熱門文章平均按讚人數：',count/sum)


#非熱門文章
data2 = json.loads(response2)

sum2 = 0  #非熱門文章數
for profile in data2:
    profile['title']
    sum2+=1

count = 0
for info in data2:
    info['commentCount']
    count+=info['commentCount']
print('非熱門文章平均留言人數：',count/sum2)

count = 0
for info in data2:
    info['likeCount']
    count+=info['likeCount']
print('非熱門文章平均按讚人數：',count/sum2)
# Out:
# 熱門文章平均留言人數： 6.9
# 熱門文章平均按讚人數： 146.9
# 非熱門文章平均留言人數： 1.4333333333333333
# 非熱門文章平均按讚人數： 8.0
